# %% [markdown]
# <a href="https://colab.research.google.com/github/ErgiaLativolia/Ergi.Sites/blob/main/Data_Cleaning.Nba_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/Nba_Data.csv.xlsx')
print(df)
# Out:
#     Conference   Division              Team                Player  Age  Games  \
# 0      Eastern   Atlantic    Boston Celtics          Jayson Tatum   20     79
# 1      Eastern   Atlantic    Boston Celtics          Kyrie Irving   26     67
# 2      Eastern   Atlantic    Boston Celtics          Marcus Smart   24     80
# 3      Eastern   Atlantic    Boston Celtics         Marcus Morris   29     75
# 4      Eastern   Atlantic    Boston Celtics            Al Horford   32     68
# ..         ...        ...               ...                   ...  ...    ...
# 617    Western  Southwest  Dallas Mavericks           Salah Mejri   32     36
# 618    Western  Southwest  Dallas Mavericks          Courtney Lee   33     22
# 619    Western  Southwest  Dallas Mavericks           Daryl Macon   23      8
# 620    Western  Southwest  Dallas Mavericks  Kostas Antetokounmpo   21      2
# 621    Western  Southwest  Dallas Mavericks          Ray Spalding   21      1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Conference                       622 non-null    object
#  1   Division                         622 non-null    object
#  2   Team                             622 non-null    object
#  3   Player                           622 non-null    object
#  4   Age                              622 non-null    int64
#  5   Games                            622 non-null    int64
#  6   Games Started                    622 non-null    int64
#  7   Minutes Played                   622 non-null    int64
#  8   Field Goals                      622 non-null    int64
#  9   Field Goal Attempts              622 non-null    int64
#  10  Field Goal Percentage            616 non-null    float64
#  11  3-Point Field Goals              622 non-null    int64
# ...

# %%
Nba_Data = df

# %%
Nba_Data.head()
# Out:
#   Conference  Division            Team         Player  Age  Games  \
# 0    Eastern  Atlantic  Boston Celtics   Jayson Tatum   20     79
# 1    Eastern  Atlantic  Boston Celtics   Kyrie Irving   26     67
# 2    Eastern  Atlantic  Boston Celtics   Marcus Smart   24     80
# 3    Eastern  Atlantic  Boston Celtics  Marcus Morris   29     75
# 4    Eastern  Atlantic  Boston Celtics     Al Horford   32     68
#
#    Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 0             79            2455          466                 1036  ...
# 1             67            2214          604                 1241  ...
# 2             60            2200          239                  567  ...
# 3             53            2091          377                  844  ...
# 4             68            1973          387                  723  ...
#
#    Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 0                  855.0                  70                 407
# ...

# %%
Nba_Data.columns
# Out:
# Index(['Conference', 'Division', 'Team', 'Player', 'Age', 'Games',
#        'Games Started', 'Minutes Played', 'Field Goals', 'Field Goal Attempts',
#        'Field Goal Percentage', '3-Point Field Goals',
#        '3-Point Field Goal Attempts', '3-Point Field Goal Percentage',
#        '2-Point Field Goals', '2-Point Field Goal Attempts',
#        '2-Point Field Goal Percentage', 'Effective Field Goal Percentage',
#        'Free Throws', 'Free Throw Attempts', 'Free Throw Percentage',
#        'Offensive Rebounds', 'Defensive Rebounds', 'Total Rebounds', 'Assists',
#        'Steals', 'Blocks', 'Turnovers', 'Personal Fouls', 'Points'],
#       dtype='object')

# %%
Nba_Data.dtypes
# Out:
# Conference                          object
# Division                            object
# Team                                object
# Player                              object
# Age                                  int64
# Games                                int64
# Games Started                        int64
# Minutes Played                       int64
# Field Goals                          int64
# Field Goal Attempts                  int64
# Field Goal Percentage              float64
# 3-Point Field Goals                  int64
# 3-Point Field Goal Attempts          int64
# 3-Point Field Goal Percentage      float64
# 2-Point Field Goals                  int64
# 2-Point Field Goal Attempts          int64
# 2-Point Field Goal Percentage      float64
# Effective Field Goal Percentage     object
# Free Throws                          int64
# Free Throw Attempts                  int64
# Free Throw Percentage              float64
# Offensive Rebounds                   int64
# ...

# %%
Nba_Data.isnull().values.any()
Nba_Data.isnull().values.sum()
Nba_Data.isnull().sum()*100/Nba_Data.shape[0]
# Out:
# Conference                         0.000000
# Division                           0.000000
# Team                               0.000000
# Player                             0.000000
# Age                                0.000000
# Games                              0.000000
# Games Started                      0.000000
# Minutes Played                     0.000000
# Field Goals                        0.000000
# Field Goal Attempts                0.000000
# Field Goal Percentage              0.964630
# 3-Point Field Goals                0.000000
# 3-Point Field Goal Attempts        0.000000
# 3-Point Field Goal Percentage      7.073955
# 2-Point Field Goals                0.000000
# 2-Point Field Goal Attempts        0.000000
# 2-Point Field Goal Percentage      2.411576
# Effective Field Goal Percentage    0.964630
# Free Throws                        0.000000
# Free Throw Attempts                0.000000
# Free Throw Percentage              6.591640
# ...

# %%
#Menghapus missing value pada data dalam keseluruhan baris (row)
Nba_Data.dropna(inplace=True, axis=1)

# %%
Nba_Data.shape
Nba_Data.isnull().sum()
# Out:
# Conference                     0
# Division                       0
# Team                           0
# Player                         0
# Age                            0
# Games                          0
# Games Started                  0
# Minutes Played                 0
# Field Goals                    0
# Field Goal Attempts            0
# 3-Point Field Goals            0
# 3-Point Field Goal Attempts    0
# 2-Point Field Goals            0
# 2-Point Field Goal Attempts    0
# Free Throws                    0
# Free Throw Attempts            0
# Offensive Rebounds             0
# Defensive Rebounds             0
# Total Rebounds                 0
# Assists                        0
# Steals                         0
# Blocks                         0
# Turnovers                      0
# Personal Fouls                 0
# Points                         0
# dtype: int64

# %%
Nba_Data.head(10)
# Out:
#   Conference  Division            Team          Player  Age  Games  \
# 0    Eastern  Atlantic  Boston Celtics    Jayson Tatum   20     79
# 1    Eastern  Atlantic  Boston Celtics    Kyrie Irving   26     67
# 2    Eastern  Atlantic  Boston Celtics    Marcus Smart   24     80
# 3    Eastern  Atlantic  Boston Celtics   Marcus Morris   29     75
# 4    Eastern  Atlantic  Boston Celtics      Al Horford   32     68
# 5    Eastern  Atlantic  Boston Celtics    Jaylen Brown   22     74
# 6    Eastern  Atlantic  Boston Celtics  Gordon Hayward   28     72
# 7    Eastern  Atlantic  Boston Celtics    Terry Rozier   24     79
# 8    Eastern  Atlantic  Boston Celtics    Daniel Theis   26     66
# 9    Eastern  Atlantic  Boston Celtics     Aron Baynes   32     51
#
#    Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 0             79            2455          466                 1036  ...
# 1             67            2214          604                 1241  ...
# ...

# %%
print("Export to csv..")
Nba_Data.to_csv("Nba_Data.csv",index=False)
# Out:
# Export to csv..

# %%
print("Done!")
# Out:
# Done!
