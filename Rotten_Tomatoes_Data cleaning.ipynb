# %% [markdown]
# <a href="https://colab.research.google.com/github/ErgiaLativolia/Ergi.Sites/blob/main/Rotten_Tomatoes_Data%20cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Rotten Tomatoes top.csv ')

# %%
df.head()
# Out:
#                   Title               Genre In Theaters Critics Score  \
# 0      12 Years a Slave               Drama  2013-10-18           95%
# 1  20 Feet From Stardom         Documentary  2013-06-14           99%
# 2              45 Years               Drama  2015-12-23           97%
# 3           All Is Lost  Action & Adventure  2013-10-18           94%
# 4         Amazing Grace         Documentary  2019-04-05           99%
#
#    Number of Critic Ratings Audience Score  Number of User Ratings  \
# 0                       359            90%                140025.0
# 1                       125            82%                 13479.0
# 2                       203            67%                 13732.0
# 3                       234            63%                 40556.0
# 4                       149            82%                   291.0
#
#          Budget Box Office US & Canada Box Office Worldwide  Runtime Minutes  \
# ...

# %%
rotten_tomatoes = df

# %%
rotten_tomatoes.head()
# Out:
#                   Title               Genre In Theaters Critics Score  \
# 0      12 Years a Slave               Drama  2013-10-18           95%
# 1  20 Feet From Stardom         Documentary  2013-06-14           99%
# 2              45 Years               Drama  2015-12-23           97%
# 3           All Is Lost  Action & Adventure  2013-10-18           94%
# 4         Amazing Grace         Documentary  2019-04-05           99%
#
#    Number of Critic Ratings Audience Score  Number of User Ratings  \
# 0                       359            90%                140025.0
# 1                       125            82%                 13479.0
# 2                       203            67%                 13732.0
# 3                       234            63%                 40556.0
# 4                       149            82%                   291.0
#
#          Budget Box Office US & Canada Box Office Worldwide  Runtime Minutes  \
# ...

# %%
rotten_tomatoes.columns
# Out:
# Index(['Title', 'Genre', 'In Theaters', 'Critics Score',
#        'Number of Critic Ratings', 'Audience Score', 'Number of User Ratings',
#        'Budget', 'Box Office US & Canada', 'Box Office Worldwide',
#        'Runtime Minutes', 'Synopsis', 'Critics Consensus', 'Studio',
#        'Content Rating', 'URL'],
#       dtype='object')

# %%
rotten_tomatoes.dtypes
# Out:
# Title                        object
# Genre                        object
# In Theaters                  object
# Critics Score                object
# Number of Critic Ratings      int64
# Audience Score               object
# Number of User Ratings      float64
# Budget                       object
# Box Office US & Canada       object
# Box Office Worldwide         object
# Runtime Minutes               int64
# Synopsis                     object
# Critics Consensus            object
# Studio                       object
# Content Rating               object
# URL                          object
# dtype: object

# %%
rotten_tomatoes.isnull().values.any()
rotten_tomatoes.isnull().values.sum()
rotten_tomatoes.isnull().sum()*100/rotten_tomatoes.shape[0]
# Out:
# Title                        0.0
# Genre                        0.0
# In Theaters                  0.0
# Critics Score                0.0
# Number of Critic Ratings     0.0
# Audience Score               0.0
# Number of User Ratings       0.0
# Budget                      13.5
# Box Office US & Canada       0.0
# Box Office Worldwide         0.5
# Runtime Minutes              0.0
# Synopsis                     0.0
# Critics Consensus            0.0
# Studio                       0.0
# Content Rating               0.0
# URL                          0.0
# dtype: float64

# %%
rotten_tomatoes.dropna(inplace=True, axis=1)

# %%
rotten_tomatoes.isnull().values.any()
rotten_tomatoes.isnull().values.sum()
rotten_tomatoes.isnull().sum()*100/rotten_tomatoes.shape[0]
# Out:
# Title                       0.0
# Genre                       0.0
# In Theaters                 0.0
# Critics Score               0.0
# Number of Critic Ratings    0.0
# Audience Score              0.0
# Number of User Ratings      0.0
# Box Office US & Canada      0.0
# Runtime Minutes             0.0
# Synopsis                    0.0
# Critics Consensus           0.0
# Studio                      0.0
# Content Rating              0.0
# URL                         0.0
# dtype: float64

# %%
rotten_tomatoes.head()
# Out:
#                   Title               Genre In Theaters Critics Score  \
# 0      12 Years a Slave               Drama  2013-10-18           95%
# 1  20 Feet From Stardom         Documentary  2013-06-14           99%
# 2              45 Years               Drama  2015-12-23           97%
# 3           All Is Lost  Action & Adventure  2013-10-18           94%
# 4         Amazing Grace         Documentary  2019-04-05           99%
#
#    Number of Critic Ratings Audience Score  Number of User Ratings  \
# 0                       359            90%                140025.0
# 1                       125            82%                 13479.0
# 2                       203            67%                 13732.0
# 3                       234            63%                 40556.0
# 4                       149            82%                   291.0
#
#   Box Office US & Canada  Runtime Minutes  \
# 0           $50,628,650               134
# 1            $4,946,445                89
# ...

# %%
print("Export to csv..")
rotten_tomatoes.to_csv("rotten_tomatoes_data.csv",index=False)
# Out:
# Export to csv..

# %%
print("Done!")
# Out:
# Done!
